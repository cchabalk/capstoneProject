# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
The raw code for this IPython notebook is by default hidden for easier reading.
To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# The raw code for this IPython notebook is by default hidden for easier reading.
# To toggle on/off the raw code, click <a href="javascript:code_toggle()">here</a>.

# %%
from IPython.display import Image

# %% [markdown]
# # Used car purchasing and market overview analysis suite

# %% [markdown]
# <p>Features:</p>
#
# <ul>
# <li>Import data from several websites</li>
# <li>Rich plots for identifying trends in prices, mileage, year, and color</li>
# </ul>
#
#
# <p>Two modes</p>
#
# <ul>
# <li>Single car mode - personal purchase</li>
# <li>Market overview - analyst information</li>
# </ul>

# %% [markdown]
# <p>Import statements and function definitions</p>

# %%
import requests
import re
from bs4 import BeautifulSoup
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import zoomed_inset_axes
# %matplotlib inline
import matplotlib.colors as colors
import matplotlib.cm as cmx

from IPython.display import Image

# %% [markdown]
# <p> Import data from a website or a file </p>

# %%
#import data from a file or from a website
def importData(importTarget):
    if (importTarget[0:4]=="http") or (importTarget[0:3]=="www"):
        print('weblink')
        #r  = requests.get("http://" +importTargt)
        #data = r.text
        #soup = BeautifulSoup(data)
    else: 
        print('file')
        soup = BeautifulSoup(open(importTarget))
        
    origin = determineOrigin(soup)
    cars = parseData(soup,origin)
    return cars

# %%
def determineOrigin(soup):
    try:
        temp = soup.find_all("title")[0].text.find("Autotrader")
        if temp>-1:
            origin = 'Autotrader'
    except ValueError:
        print("")
    try:
        temp = soup.find_all("title")[0].text.find("Cars.com")
        if temp>-1:
            origin = 'Cars'
    except ValueError:
        print("")
    return origin

# %% [markdown]
# <p> Send data to the proper filter to be parsed </p>

# %%
def parseData(soup,origin):
    if origin=="Autotrader":
        cars = parseAutotrader(soup)
    if origin=="Cars":
        cars = parseCars(soup)
    return cars

# %% [markdown]
# <p> The remaining archetecture is currently being revised.  It would not be beneficial to present it in this notebook </p>

# %% [markdown]
# # Representative Results

# %%
Image(filename='carColorPriceVsMiles.png')

# %%
Image(filename='carPricePolar.png')

# %%
Image(filename='carPriceVsMiles.png')
